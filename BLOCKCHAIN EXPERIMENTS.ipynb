# %% [markdown]
# **BLOCKCHAIN AND WEB3.PY**

# %%
# !pip install web3
# Out:
# ...
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    --------------- ------------------------ 0.5/1.4 MB 2.4 MB/s eta 0:00:01
#    ------------------------------ --------- 1.0/1.4 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 2.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/587.5 kB ? eta -:--:--
#    ----------------------------------- ---- 524.3/587.5 kB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 587.5/587.5 kB 1.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----------- ---------------------------- 0.5/1.8 MB 1.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.0/1.8 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.6/1.8 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 1.9 MB/s eta 0:00:00
# ...
