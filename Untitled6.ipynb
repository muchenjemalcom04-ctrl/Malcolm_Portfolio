# %% [markdown]
# **BLOCKCHAIN AND WEB3.PY**

# %%
# !pip install Web3.py
# Out:
# ERROR: Could not find a version that satisfies the requirement Web3.py (from versions: none)
# ERROR: No matching distribution found for Web3.py
