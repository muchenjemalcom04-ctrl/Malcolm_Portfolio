# %% [markdown]
# **MALCOLM'S FINTECH PLAYGROUND**

# %%
pip install yfinance matplotlib pandas
# Out:
# ...
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      -------------------- ------------------- 1.6/3.0 MB 9.4 MB/s eta 0:00:01
#      ---------------------------------------- 3.0/3.0 MB 8.1 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 6.8 MB/s eta 0:00:00
# ...
#   Created wheel for peewee: filename=peewee-3.18.1-py3-none-any.whl size=139100 sha256=059392315c0efcbd9a5c189d5be21963f01105c0a6e529fc2d3e5ee515dd0b3d
# ...

# %%
import numpy as np
